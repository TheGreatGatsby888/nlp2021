# %%
import numpy as np, pandas as pd, tensorflow as tf, requests as rqst, io
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from tensorflow.keras import layers

rnd = np.random.randint

folder = '/content/drive/MyDrive/Colab Notebooks/NLP_labs/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = open(folder+'sentences.txt')
sentences = file.read().split('. ')[:-1]
sentences
# Out:
# ['which input is most helpful is classifying data without error? These input-weight products are summed and then the sum is passed through a node’s so-called activation function, to determine whether and to what extent that signal should progress further through the network to affect the ultimate outcome, say, an act of classification',
#  'And thanks to the demand from gamers around the world, GPUs (graphics processing units) make it possible for us to leverage deep learning algorithms to build and train models with impressive results in a time-efficient manner! So to all the parents who don’t like your kids playing games: Gaming has its silver lining…',
#  'Is the dataset you need publicly available, or can you create it (with a data annotation service like Scale or AWS Mechanical Turk)? In this example, spam emails would be labeled as spam, and the labels would enable the algorithm to map from inputs to the classifications you care about',
#  '(Neural networks can also extract features that are fed to other algorithms for clustering and classification; so you can think of deep neural networks as components of larger machine-learning applications involving algorithms for reinforcement learning, classification and regression)',
#  'Deep learning algorithms have improved over the past few decades and developers around the world have contributed to open source frameworks like TensorFlow, Theano, Keras, and Torch, all of which make it easy for people to build deep learning algorithms as if playing with LEGO pieces',
#  'What outcomes do I care about? In a classification problem, those outcomes are labels that could be applied to data: for example, spam or not_spam in an email filter, good_guy or bad_guy in fraud detection, angry_customer or happy_customer in customer relationship management',
#  'Who would have thought that DeepMind’s AlphaGo could defeat Lee Sedol, one of the best Go players, in the deepest board game which boasts more possible moves than there are atoms in the entire universe? A lot of people, including me, never saw it coming',
#  'If data is the crude oil, databases and data warehouses are the drilling rigs that digs and pumps the data on the internet, then think of deep learning as the oil refinery that finally turns crude oil into all the useful and insightful final products',
#  'It is known as a “universal approximator”, because it can learn to approximate an unknown function f(x) = y between any input x and any output y, assuming they are related at all (by correlation or causation, for example)',
#  'A node combines input from the data with a set of coefficients, or weights, that either amplify or dampen that input, thereby assigning significance to inputs with regard to the task the algorithm is trying to learn; eg',
#  'Other types of problems include anomaly detection (useful in fraud detection and predictive maintenance of manufacturing equipment), and clustering, which is useful in recommendation systems that surface similarities',
#  'All classification tasks depend upon labeled datasets; that is, humans must transfer their knowledge to the dataset in order for a neural network to learn the correlation between labels and data',
#  'You’ve probably read on the news and know that deep learning is the secret recipe behind many exciting developments and has made many of our wildest dreams and perhaps also nightmares come true',
#  'There could be a lot of “fossil fuels” hidden underground, and there are a lot of drills and pumps in the market, but without the right refinery tools, you ain’t gonna get anything valuable',
#  'In the process of learning, a neural network finds the right f, or the correct manner of transforming x into y, whether that be f(x) = 3x + 12 or f(x) = 9x - 01',
#  'During the training of the network, you need to select such weights for each of the neurons that the output provided by the whole network would be true-to-life',
#  'The patterns they recognize are numerical, contained in vectors, into which all real-world data, be it images, sound, text or time series, must be translated',
#  'The results of the neuron with the greater weight will be dominant in the next neuron, while information from less ‘weighty’ neurons will not be passed over',
#  'They help to group unlabeled data according to similarities among the example inputs, and they classify data when they have a labeled dataset to train on',
#  'A node is just a place where computation happens, loosely patterned on a neuron in the human brain, which fires when it encounters sufficient stimuli',
#  'ANN can have millions of neurons connected into one system, which makes it extremely successful at analyzing and even memorizing various information',
#  'We’re also moving toward a world of smarter agents that combine neural networks with other algorithms like reinforcement learning to attain goals',
#  'By the same token, exposed to enough of the right data, deep learning is able to establish correlations between present events and future events',
#  'What kind of problems does deep learning solve, and more importantly, can it solve yours? To know the answer, you need to ask a few questions:',
#  'Any labels that humans can generate, any outcomes that you care about and which correlate to data, can be used to train a neural network',
#  'With classification, deep learning is able to establish correlations between, say, pixels in an image and the name of a person',
#  'Neural networks are a set of algorithms, modeled loosely after the human brain, that are designed to recognize patterns',
#  'Classify text as spam (in emails), or fraudulent (in insurance claims); recognize sentiment in text (customer feedback)',
#  'For example, we want our neural network to distinguish between photos of cats and dogs and provide plenty of examples',
#  'If you are a data scientist working on a problem, you can’t trust anyone to tell you whether the data is good enough',
#  'Here is a video for those who want to dive deeper into the technical details of how artificial neural networks work',
#  'Machine learning attempts to extract new knowledge from a large set of pre-processed data loaded into the system',
#  'Let’s imagine that we have three features and three neurons, each of which is connected with all these features',
#  'Given a time series, deep learning may read a string of number and predict the number most likely to occur next',
#  'The good news is, we are not going to run out of data and our “refinery machine” is getting better and better',
#  'Deep learning is the name we use for “stacked neural networks”; that is, networks composed of several layers',
#  'In many cases, unusual behavior correlates highly with things you want to detect and prevent, such as fraud',
#  'Customer churn (predicting the likelihood that a customer will leave, based on web activity and metadata)',
#  'You can think of them as a clustering and classification layer on top of the data you store and manage',
#  'Do I have the right data? For example, if you have a classification problem, you’ll need labeled data',
#  'One law of machine learning is: the more data an algorithm can train on, the more accurate it will be',
#  'Anomaly detection: The flipside of detecting similarities is detecting anomalies, or unusual behavior',
#  'In the meantime, as long as the data isn’t garbage-in, then there’s no garbage-out from deep learning',
#  'They interpret sensory data through a kind of machine perception, labeling or clustering raw input',
#  'Deep learning doesn’t necessarily care about time, or the fact that something hasn’t happened yet',
#  'We use calculus magic and repeatedly optimize the weights of the network until the delta is zero',
#  'With that brief overview of deep learning use cases, let’s look at what neural nets are made of',
#  'An artificial neural network represents the structure of a human brain modeled on the computer',
#  'Once the delta is zero or close to it, our model is correctly able to predict our example data',
#  'Detect voices, identify speakers, transcribe speech to text, recognize sentiment in voices',
#  'Health breakdowns (strokes, heart attacks based on vital stats and data from wearables)',
#  'Detect faces, identify people in images, recognize facial expressions (angry, joyful)',
#  'As you can see, with neural networks, we’re moving towards a world of fewer surprises',
#  'Therefore, unsupervised learning has the potential to produce highly accurate models',
#  'Programmers need to formulate the rules for the machine, and it learns based on them',
#  'You want to get some results and provide information to the network to learn from',
#  'Large corporations and young startups alike are all gold-rushing this fancy field',
#  'Delta is the difference between the data and the output of the neural network',
#  'Each of the neurons has its own weights that are used to weight the features',
#  'If you think big data is important, then you should care about deep learning',
#  'You can’t know that you have the right data until you get your hands on it',
#  '’s post on blockchains for AI as a solution for data to have reputation!)',
#  'One can say that the matrix of weights governs the whole neural system',
#  'Search: Comparing documents, images or sounds to surface similar items',
#  'Also, this “oil refinery” is improving on both software and hardware',
#  'Identify objects in images (stop signs, pedestrians, lane markers…)',
#  'Deep learning is probably one of the hottest tech topics right now',
#  'The better we can predict, the better we can prevent and pre-empt',
#  'A synapse is what connects the neurons like an electricity cable',
#  'So data, unlike oil, is “sustainable” and growing “explosively”',
#  'If the signals passes through, the neuron has been “activated”',
#  'Deep learning is beating us in the most challenging board game',
#  'Only direct exploration of the data will answer this question',
#  'The weights also add to the changes in the input information',
#  'Deep learning does not require labels to detect similarities',
#  'Hardware breakdowns (data centers, manufacturing, transport)',
#  'Today, just about doing anything online will generate data',
#  'It consists of neurons and synapses organized into layers',
#  'Sometimes, a human might intervene to correct its errors',
#  'Clustering or grouping is the detection of similarities',
#  'Learning without labels is called unsupervised learning',
#  'Every neuron processes input data to extract a feature',
#  'It can run regression between the past and the future',
#  'Neural networks are trained like any other algorithm',
#  'Here are a few examples of what deep learning can do',
#  'When is the AI awakening? Some think it will be soon',
#  'Unlabeled data is the majority of data in the world',
#  'says that data is the new oil in the 21st Century',
#  'The future event is like the label in a sense',
#  'Neural networks help us cluster and classify',
#  'Employee turnover (ditto, but for employees)',
#  'Not zero surprises, just marginally fewer',
#  'It’s part of the data-driven big picture',
#  'You might call this a static prediction',
#  'That’s why deep learning is important',
#  'Deep learning maps inputs to outputs',
#  'This is known as supervised learning',
#  'Learn to build AI in simulations »',
#  'Predictive Analytics: Regressions']

# %% [markdown]
# ### Підібрати наукові статті за обраним напрямком англійською мовою, з яких вилучити 100 речень, які найбільш відповідають зазначеному напрямку

# %%
sent_df = []
for sent in sentences:
  sent_df.append({'Sentence':sent, 'Label':'Reinforcement Learning'})

sent_df
# Out:
# [{'Label': 'Reinforcement Learning',
#   'Sentence': 'which input is most helpful is classifying data without error? These input-weight products are summed and then the sum is passed through a node’s so-called activation function, to determine whether and to what extent that signal should progress further through the network to affect the ultimate outcome, say, an act of classification'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'And thanks to the demand from gamers around the world, GPUs (graphics processing units) make it possible for us to leverage deep learning algorithms to build and train models with impressive results in a time-efficient manner! So to all the parents who don’t like your kids playing games: Gaming has its silver lining…'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Is the dataset you need publicly available, or can you create it (with a data annotation service like Scale or AWS Mechanical Turk)? In this example, spam emails would be labeled as spam, and the labels would enable the algorithm to map from inputs to the classifications you care about'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': '(Neural networks can also extract features that are fed to other algorithms for clustering and classification; so you can think of deep neural networks as components of larger machine-learning applications involving algorithms for reinforcement learning, classification and regression)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Deep learning algorithms have improved over the past few decades and developers around the world have contributed to open source frameworks like TensorFlow, Theano, Keras, and Torch, all of which make it easy for people to build deep learning algorithms as if playing with LEGO pieces'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'What outcomes do I care about? In a classification problem, those outcomes are labels that could be applied to data: for example, spam or not_spam in an email filter, good_guy or bad_guy in fraud detection, angry_customer or happy_customer in customer relationship management'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Who would have thought that DeepMind’s AlphaGo could defeat Lee Sedol, one of the best Go players, in the deepest board game which boasts more possible moves than there are atoms in the entire universe? A lot of people, including me, never saw it coming'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'If data is the crude oil, databases and data warehouses are the drilling rigs that digs and pumps the data on the internet, then think of deep learning as the oil refinery that finally turns crude oil into all the useful and insightful final products'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'It is known as a “universal approximator”, because it can learn to approximate an unknown function f(x) = y between any input x and any output y, assuming they are related at all (by correlation or causation, for example)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'A node combines input from the data with a set of coefficients, or weights, that either amplify or dampen that input, thereby assigning significance to inputs with regard to the task the algorithm is trying to learn; eg'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Other types of problems include anomaly detection (useful in fraud detection and predictive maintenance of manufacturing equipment), and clustering, which is useful in recommendation systems that surface similarities'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'All classification tasks depend upon labeled datasets; that is, humans must transfer their knowledge to the dataset in order for a neural network to learn the correlation between labels and data'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'You’ve probably read on the news and know that deep learning is the secret recipe behind many exciting developments and has made many of our wildest dreams and perhaps also nightmares come true'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'There could be a lot of “fossil fuels” hidden underground, and there are a lot of drills and pumps in the market, but without the right refinery tools, you ain’t gonna get anything valuable'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'In the process of learning, a neural network finds the right f, or the correct manner of transforming x into y, whether that be f(x) = 3x + 12 or f(x) = 9x - 01'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'During the training of the network, you need to select such weights for each of the neurons that the output provided by the whole network would be true-to-life'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'The patterns they recognize are numerical, contained in vectors, into which all real-world data, be it images, sound, text or time series, must be translated'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'The results of the neuron with the greater weight will be dominant in the next neuron, while information from less ‘weighty’ neurons will not be passed over'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'They help to group unlabeled data according to similarities among the example inputs, and they classify data when they have a labeled dataset to train on'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'A node is just a place where computation happens, loosely patterned on a neuron in the human brain, which fires when it encounters sufficient stimuli'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'ANN can have millions of neurons connected into one system, which makes it extremely successful at analyzing and even memorizing various information'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'We’re also moving toward a world of smarter agents that combine neural networks with other algorithms like reinforcement learning to attain goals'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'By the same token, exposed to enough of the right data, deep learning is able to establish correlations between present events and future events'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'What kind of problems does deep learning solve, and more importantly, can it solve yours? To know the answer, you need to ask a few questions:'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Any labels that humans can generate, any outcomes that you care about and which correlate to data, can be used to train a neural network'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'With classification, deep learning is able to establish correlations between, say, pixels in an image and the name of a person'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Neural networks are a set of algorithms, modeled loosely after the human brain, that are designed to recognize patterns'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Classify text as spam (in emails), or fraudulent (in insurance claims); recognize sentiment in text (customer feedback)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'For example, we want our neural network to distinguish between photos of cats and dogs and provide plenty of examples'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'If you are a data scientist working on a problem, you can’t trust anyone to tell you whether the data is good enough'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Here is a video for those who want to dive deeper into the technical details of how artificial neural networks work'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Machine learning attempts to extract new knowledge from a large set of pre-processed data loaded into the system'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Let’s imagine that we have three features and three neurons, each of which is connected with all these features'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Given a time series, deep learning may read a string of number and predict the number most likely to occur next'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'The good news is, we are not going to run out of data and our “refinery machine” is getting better and better'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Deep learning is the name we use for “stacked neural networks”; that is, networks composed of several layers'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'In many cases, unusual behavior correlates highly with things you want to detect and prevent, such as fraud'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Customer churn (predicting the likelihood that a customer will leave, based on web activity and metadata)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'You can think of them as a clustering and classification layer on top of the data you store and manage'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Do I have the right data? For example, if you have a classification problem, you’ll need labeled data'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'One law of machine learning is: the more data an algorithm can train on, the more accurate it will be'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Anomaly detection: The flipside of detecting similarities is detecting anomalies, or unusual behavior'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'In the meantime, as long as the data isn’t garbage-in, then there’s no garbage-out from deep learning'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'They interpret sensory data through a kind of machine perception, labeling or clustering raw input'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Deep learning doesn’t necessarily care about time, or the fact that something hasn’t happened yet'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'We use calculus magic and repeatedly optimize the weights of the network until the delta is zero'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'With that brief overview of deep learning use cases, let’s look at what neural nets are made of'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'An artificial neural network represents the structure of a human brain modeled on the computer'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Once the delta is zero or close to it, our model is correctly able to predict our example data'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Detect voices, identify speakers, transcribe speech to text, recognize sentiment in voices'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Health breakdowns (strokes, heart attacks based on vital stats and data from wearables)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Detect faces, identify people in images, recognize facial expressions (angry, joyful)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'As you can see, with neural networks, we’re moving towards a world of fewer surprises'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Therefore, unsupervised learning has the potential to produce highly accurate models'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Programmers need to formulate the rules for the machine, and it learns based on them'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'You want to get some results and provide information to the network to learn from'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Large corporations and young startups alike are all gold-rushing this fancy field'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Delta is the difference between the data and the output of the neural network'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Each of the neurons has its own weights that are used to weight the features'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'If you think big data is important, then you should care about deep learning'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'You can’t know that you have the right data until you get your hands on it'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': '’s post on blockchains for AI as a solution for data to have reputation!)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'One can say that the matrix of weights governs the whole neural system'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Search: Comparing documents, images or sounds to surface similar items'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Also, this “oil refinery” is improving on both software and hardware'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Identify objects in images (stop signs, pedestrians, lane markers…)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Deep learning is probably one of the hottest tech topics right now'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'The better we can predict, the better we can prevent and pre-empt'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'A synapse is what connects the neurons like an electricity cable'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'So data, unlike oil, is “sustainable” and growing “explosively”'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'If the signals passes through, the neuron has been “activated”'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Deep learning is beating us in the most challenging board game'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Only direct exploration of the data will answer this question'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'The weights also add to the changes in the input information'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Deep learning does not require labels to detect similarities'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Hardware breakdowns (data centers, manufacturing, transport)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Today, just about doing anything online will generate data'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'It consists of neurons and synapses organized into layers'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Sometimes, a human might intervene to correct its errors'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Clustering or grouping is the detection of similarities'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Learning without labels is called unsupervised learning'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Every neuron processes input data to extract a feature'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'It can run regression between the past and the future'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Neural networks are trained like any other algorithm'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Here are a few examples of what deep learning can do'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'When is the AI awakening? Some think it will be soon'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Unlabeled data is the majority of data in the world'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'says that data is the new oil in the 21st Century'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'The future event is like the label in a sense'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Neural networks help us cluster and classify'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Employee turnover (ditto, but for employees)'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Not zero surprises, just marginally fewer'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'It’s part of the data-driven big picture'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'You might call this a static prediction'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'That’s why deep learning is important'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Deep learning maps inputs to outputs'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'This is known as supervised learning'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Learn to build AI in simulations »'},
#  {'Label': 'Reinforcement Learning',
#   'Sentence': 'Predictive Analytics: Regressions'}]

# %% [markdown]
# ### Створити та зберегти у .csv файл pandas DataFrame з обраних речень із указанням в окремому ствопчику назви напрямку (ця назва має бути однаковою для усіх речень)

# %%
sent_df = pd.DataFrame(data=sent_df, columns=['Sentence', 'Label'])

sent_df.to_csv(folder+'sentences.csv')

sent_df
# Out:
#                                              Sentence                   Label
# 0   which input is most helpful is classifying dat...  Reinforcement Learning
# 1   And thanks to the demand from gamers around th...  Reinforcement Learning
# 2   Is the dataset you need publicly available, or...  Reinforcement Learning
# 3   (Neural networks can also extract features tha...  Reinforcement Learning
# 4   Deep learning algorithms have improved over th...  Reinforcement Learning
# ..                                                ...                     ...
# 94              That’s why deep learning is important  Reinforcement Learning
# 95               Deep learning maps inputs to outputs  Reinforcement Learning
# 96               This is known as supervised learning  Reinforcement Learning
# 97                 Learn to build AI in simulations »  Reinforcement Learning
# 98                  Predictive Analytics: Regressions  Reinforcement Learning
#
# [99 rows x 2 columns]

# %% [markdown]
# ### Здійснити підготовку набору даних до подальшого моделювання (tokenization&embedding, train_test_split)

# %% [markdown]
# ### Train/Test Split

# %%
from sklearn.model_selection import train_test_split
train_split, test_split = train_test_split(sent_df, train_size=0.8, test_size=0.2)
train_split
# Out:
#                                              Sentence                   Label
# 10  Other types of problems include anomaly detect...  Reinforcement Learning
# 52  As you can see, with neural networks, we’re mo...  Reinforcement Learning
# 91          Not zero surprises, just marginally fewer  Reinforcement Learning
# 71  Deep learning is beating us in the most challe...  Reinforcement Learning
# 41  Anomaly detection: The flipside of detecting s...  Reinforcement Learning
# ..                                                ...                     ...
# 19  A node is just a place where computation happe...  Reinforcement Learning
# 61  ’s post on blockchains for AI as a solution fo...  Reinforcement Learning
# 39  Do I have the right data? For example, if you ...  Reinforcement Learning
# 56  Large corporations and young startups alike ar...  Reinforcement Learning
# 95               Deep learning maps inputs to outputs  Reinforcement Learning
#
# [79 rows x 2 columns]

# %% [markdown]
# #### Vectorization

# %%
max_tokens = 10000

tokens_count = 0
for sent in sentences:
  tokens_count+=len(sent.split())
avg_tokens = round(tokens_count/len(sentences))
avg_tokens
# Out:
# 18

# %%
text_vectorizer = TextVectorization(max_tokens=max_tokens, # how many words in the vocabulary (all of the different words in your text)
                                    standardize="lower_and_strip_punctuation", # how to process text
                                    split="whitespace", # how to split tokens
                                    ngrams=None, # create groups of n-words?
                                    output_mode="int", # how to map tokens to numbers
                                    output_sequence_length=avg_tokens, # how long should the output sequence of tokens be?
                                    pad_to_max_tokens=True)
text_vectorizer

# %%
text_vectorizer.adapt(sent_df['Sentence'])

# %%
text_vectorizer(sent_df['Sentence'])
# Out:
# <tf.Tensor: shape=(99, 18), dtype=int64, numpy=
# array([[ 26,  36,   6, ...,   5,  69,   2],
#        [  5, 302,   3, ...,  16, 168,  18],
#        [  6,   2, 123, ..., 659, 347,  34],
#        ...,
#        [ 43,   6, 193, ...,   0,   0,   0],
#        [ 58,   3, 127, ...,   0,   0,   0],
#        [167, 664, 368, ...,   0,   0,   0]])>

# %%
print(f"Most Used: {text_vectorizer.get_vocabulary()[:5]}")
print(f"Most Unused: {text_vectorizer.get_vocabulary()[-5:]}")
# Out:
# Most Used: ['', '[UNK]', 'the', 'to', 'of']
# Most Unused: ['9x', '3x', '21st', '12', '01']

# %% [markdown]
# #### Embedding

# %%
embedding = layers.Embedding(input_dim=max_tokens, # set input shape
                             output_dim=128, # set size of embedding vector
                             embeddings_initializer="uniform", # default, intialize randomly
                             input_length=avg_tokens) # how long is each input

embedding(text_vectorizer(sent_df['Sentence']))
# Out:
# <tf.Tensor: shape=(99, 18, 128), dtype=float32, numpy=
# array([[[ 0.02649392,  0.03455598,  0.03693109, ...,  0.04001713,
#           0.01619015,  0.0329239 ],
#         [ 0.01735726,  0.03349419,  0.0407011 , ...,  0.03383284,
#          -0.01569266,  0.04784724],
#         [ 0.04263499, -0.0074714 ,  0.00940112, ..., -0.04725128,
#           0.01254864, -0.04559779],
#         ...,
#         [-0.04451725, -0.01108446, -0.03888494, ..., -0.01655387,
#          -0.0312529 ,  0.01859114],
#         [ 0.04264941, -0.03020682, -0.00348865, ..., -0.02534142,
#           0.02340144, -0.04692082],
#         [-0.00790466, -0.03566766,  0.01512972, ..., -0.01683168,
#           0.00136293,  0.0098209 ]],
#
#        [[-0.04451725, -0.01108446, -0.03888494, ..., -0.01655387,
#          -0.0312529 ,  0.01859114],
#         [-0.01716309,  0.00108542,  0.04675511, ..., -0.03306841,
#           0.04894564,  0.04943749],
#         [ 0.00415247, -0.01249785,  0.0309405 , ...,  0.03757297,
#           0.035754  ,  0.00465264],
#         ...,
#         [ 0.0247542 ,  0.0038073 ,  0.01854941, ..., -0.02323935,
#          -0.01308359,  0.02457741],
#         [ 0.03935542, -0.04673872,  0.01283188, ...,  0.04067529,
#          -0.03982031, -0.0375074 ],
#         [-0.03657741,  0.02786649, -0.03068587, ..., -0.00238312,
#          -0.00331079,  0.04984258]],
#
#        [[ 0.04263499, -0.0074714 ,  0.00940112, ..., -0.04725128,
#           0.01254864, -0.04559779],
#         [-0.00790466, -0.03566766,  0.01512972, ..., -0.01683168,
#           0.00136293,  0.0098209 ],
#         [ 0.01010277, -0.01251065,  0.00981039, ..., -0.02516512,
#           0.04089098,  0.02047778],
#         ...,
#         [-0.02926108, -0.047729  , -0.04168003, ...,  0.00429782,
#          -0.00422627, -0.03896073],
#         [ 0.02632607, -0.00345106, -0.0478882 , ..., -0.01121092,
#           0.03133693,  0.01471896],
#         [ 0.043463  , -0.03746588,  0.00089633, ..., -0.04439256,
#          -0.02724456,  0.04841633]],
#
#        ...,
#
#        [[-0.00197572,  0.00351157,  0.00925753, ..., -0.04887455,
#           0.04074741, -0.00289358],
#         [ 0.04263499, -0.0074714 ,  0.00940112, ..., -0.04725128,
#           0.01254864, -0.04559779],
#         [ 0.02867153, -0.01398962, -0.02855417, ..., -0.00847257,
#           0.03441522, -0.0007885 ],
#         ...,
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814],
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814],
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814]],
#
#        [[-0.02334505, -0.01980375,  0.02068386, ...,  0.04101804,
#          -0.02668966, -0.03254871],
#         [ 0.00415247, -0.01249785,  0.0309405 , ...,  0.03757297,
#           0.035754  ,  0.00465264],
#         [ 0.02393677, -0.03550262, -0.01042672, ...,  0.00848197,
#          -0.02318834,  0.02353679],
#         ...,
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814],
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814],
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814]],
#
#        [[-0.03785014,  0.03621617,  0.00516744, ...,  0.00458788,
#          -0.03585095, -0.00385378],
#         [ 0.00481533,  0.00030259, -0.02656264, ..., -0.04597196,
#          -0.04485377, -0.01071911],
#         [ 0.0173367 ,  0.03116235, -0.02619307, ...,  0.02848086,
#           0.00821878, -0.01488679],
#         ...,
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814],
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814],
#         [ 0.03013803, -0.02761862, -0.00908624, ..., -0.005993  ,
#          -0.02059653,  0.01310814]]], dtype=float32)>

# %% [markdown]
# ### Відповіді оформити .ipynb, .csv, .pdf документами
